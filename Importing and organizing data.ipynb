# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(np.random.random(5), name="Column 01")

# %%
ser
# Out:
# 0    0.754027
# 1    0.136386
# 2    0.380736
# 3    0.067622
# 4    0.912169
# Name: Column 01, dtype: float64

# %%
ser[2]
# Out:
# 0.38073601835842097

# %%
from pandas_datareader import data as wb

# %%
PG = wb.DataReader('PG', data_source='yahoo', start='1995-1-1')

# %%
PG
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 1995-01-03   15.625000   15.437500   15.468750   15.593750   3318400.0
# 1995-01-04   15.656250   15.312500   15.531250   15.468750   2218800.0
# 1995-01-05   15.437500   15.218750   15.375000   15.250000   2319600.0
# 1995-01-06   15.406250   15.156250   15.156250   15.281250   3438000.0
# 1995-01-09   15.406250   15.187500   15.343750   15.218750   1795200.0
# ...                ...         ...         ...         ...         ...
# 2020-01-17  127.000000  125.879997  126.349998  126.410004  11315200.0
# 2020-01-21  126.620003  124.839996  126.410004  126.089996   8553100.0
# 2020-01-22  126.680000  125.830002  126.330002  126.309998   7396700.0
# 2020-01-23  126.550003  123.650002  124.300003  124.989998  11096500.0
# 2020-01-24  126.790001  124.769997  125.220001  125.139999   9508100.0
#
#              Adj Close
# Date
# 1995-01-03    6.362394
# 1995-01-04    6.311395
# 1995-01-05    6.222139
# 1995-01-06    6.234891
# 1995-01-09    6.209391
# ...                ...
# 2020-01-17  125.663414
# 2020-01-21  125.345299
# 2020-01-22  125.563995
# 2020-01-23  124.989998
# 2020-01-24  125.139999
#
# [6310 rows x 6 columns]

# %%
PG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6310 entries, 1995-01-03 to 2020-01-24
# Data columns (total 6 columns):
# High         6310 non-null float64
# Low          6310 non-null float64
# Open         6310 non-null float64
# Close        6310 non-null float64
# Volume       6310 non-null float64
# Adj Close    6310 non-null float64
# dtypes: float64(6)
# memory usage: 345.1 KB

# %%
PG.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   6.362394
# 1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   6.311395
# 1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   6.222139
# 1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   6.234891
# 1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   6.209391

# %%
PG.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-17  127.000000  125.879997  126.349998  126.410004  11315200.0
# 2020-01-21  126.620003  124.839996  126.410004  126.089996   8553100.0
# 2020-01-22  126.680000  125.830002  126.330002  126.309998   7396700.0
# 2020-01-23  126.550003  123.650002  124.300003  124.989998  11096500.0
# 2020-01-24  126.790001  124.769997  125.220001  125.139999   9508100.0
#
#              Adj Close
# Date
# 2020-01-17  125.663414
# 2020-01-21  125.345299
# 2020-01-16  126.779999  125.589996  126.110001  126.070000   6233700.0
# 2020-01-17  127.000000  125.879997  126.349998  126.410004  11315200.0
# 2020-01-21  126.620003  124.839996  126.410004  126.089996   8553100.0
# 2020-01-22  126.680000  125.830002  126.330002  126.309998   7396700.0
# 2020-01-23  126.550003  123.650002  124.300003  124.989998  11096500.0
# 2020-01-24  126.790001  124.769997  125.220001  125.139999   9508100.0
#
#              Adj Close
# Date
# 2019-12-26  124.480438
# 2019-12-27  125.345299
# 2019-12-30  123.734871
# 2019-12-31  124.162331
# 2020-01-02  122.681129
# 2020-01-03  121.856033
# 2020-01-06  122.025024
# 2020-01-07  121.269508
# 2020-01-08  121.786446
# 2020-01-09  123.118530
# 2020-01-10  123.237823
# 2020-01-13  124.142441
# 2020-01-14  123.953568
# 2020-01-15  125.216064
# 2020-01-16  125.325417
# 2020-01-17  125.663414
# 2020-01-21  125.345299
# 2020-01-22  125.563995
# 2020-01-23  124.989998
# 2020-01-24  125.139999

# %%
tickers = ['PG', 'MSFT', 'T', 'F', 'GE']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
new_data.tail()
# Out:
#                     PG        MSFT          T     F     GE
# Date
# 2020-01-17  125.663414  167.100006  38.380001  9.16  11.81
# 2020-01-21  125.345299  166.500000  38.520000  9.21  11.66
# 2020-01-22  125.563995  165.699997  39.040001  9.16  11.37
# 2020-01-23  124.989998  166.720001  38.630001  9.14  11.77
# 2020-01-24  125.139999  165.039993  38.500000  9.00  11.71

# %%
# IEX
PG = wb.DataReader('PG', data_source='iex', start='2015-01-01')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-bf026dd3e179> in <module>
#       1 # IEX
# ----> 2 PG = wb.DataReader('PG', data_source='iex', start='2015-01-01')
#
# /usr/local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# /usr/local/lib/python3.7/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     397             retry_count=retry_count,
#     398             pause=pause,
# --> 399             session=session,
#     400         ).read()
#     401
#
# /usr/local/lib/python3.7/site-packages/pandas_datareader/iex/daily.py in __init__(self, symbols, start, end, retry_count, pause, session, chunksize, api_key)
#      62         if not api_key or not isinstance(api_key, str):
#      63             raise ValueError(
# ---> 64                 "The IEX Cloud API key must be provided either "
#      65                 "through the api_key variable or through the "
#      66                 " environment variable IEX_API_KEY"
#
# ValueError: The IEX Cloud API key must be provided either through the api_key variable or through the  environment variable IEX_API_KEY

# %%
import quandl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-c982d674eccd> in <module>
# ----> 1 import quandl
#
# ModuleNotFoundError: No module named 'quandl'
